# %% [markdown]
# ## EQUAL WEIGHTS STRATEGY

# %%
import pandas as pd 
import numpy as np 
import yfinance as yf 
import math

# %%
tickers= pd.read_csv('top_50_indian_stocks.csv')
tickers.head()
# Out:
#          Ticker               Company Name
# 0   RELIANCE.NS        Reliance Industries
# 1        TCS.NS  Tata Consultancy Services
# 2   HDFCBANK.NS                  HDFC Bank
# 3       INFY.NS                    Infosys
# 4  ICICIBANK.NS                 ICICI Bank

# %%
def fetch_market_cap(ticker_list):
    data= yf.download(ticker_list, period='1d', group_by='ticker', auto_adjust=False)
     
    stocks_data = []
    for ticker in ticker_list:
        lastest_price= data[ticker]['Close'].iloc[-1]
        market_cap=yf.Ticker(ticker).info.get('marketCap', 'N/A')

        stocks_data.append(
            {'Ticker': ticker,
             'Market Cap': market_cap,
             'Latest Price': lastest_price, })
        
    return pd.DataFrame(stocks_data)

    


tickers_list=tickers["Ticker"].values.tolist()
df=fetch_market_cap(tickers_list)
df.head()
# Out:
# [********************  42%                       ]  21 of 50 completedHTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: TATAMOTORS.NS"}}}
# [**********************74%***********            ]  37 of 50 completed$TATAMOTORS.NS: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# [*********************100%***********************]  50 of 50 completed
#
# 1 Failed download:
# ['TATAMOTORS.NS']: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: TATAMOTORS.NS"}}}
#          Ticker      Market Cap  Latest Price
# 0   RELIANCE.NS  17862863355904   1320.000000
# 1        TCS.NS   8312193548288   2297.399902
# 2   HDFCBANK.NS  11435754127360    742.700012
# ...

# %%
df = (
    df[df["Market Cap"] != "N/A"]
    .sort_values(by="Market Cap", ascending=False)
    .reset_index(drop=True)
)

df
# Out:
#            Ticker      Market Cap  Latest Price
# 0     RELIANCE.NS  17862863355904   1320.000000
# 1     HDFCBANK.NS  11435754127360    742.700012
# 2   BHARTIARTL.NS  11029219115008   1810.599976
# 3    ICICIBANK.NS   8887814062080   1239.699951
# 4         SBIN.NS   8806932152320    954.099976
# 5          TCS.NS   8312193548288   2297.399902
# 6   BAJFINANCE.NS   5528003018752    889.049988
# 7           LT.NS   5517530365952   4010.800049
# 8   HINDUNILVR.NS   4897253097472   2084.300049
# 9         INFY.NS   4867370254336   1202.500000
# 10   SUNPHARMA.NS   4310405218304   1796.500000
# 11  ADANIPORTS.NS   4109110870016   1783.500000
# 12      MARUTI.NS   4070255624192  12946.000000
# 13    ADANIENT.NS   3988625031168   2909.399902
# 14    AXISBANK.NS   3967961268224   1275.900024
# 15   KOTAKBANK.NS   3753795911680    377.399994
# 16        NTPC.NS   3672127832064    378.700012
# 17       TITAN.NS   3570002296832   4024.600098
# 18         M&M.NS   3566503985152   2970.199951
# ...

# %% [markdown]
# Taking top 10 stocks as per marketcap

# %%
df=df.head(10)
df.reset_index(drop=True, inplace=True)
df
# Out:
#           Ticker      Market Cap  Latest Price
# 0    RELIANCE.NS  17862863355904   1320.000000
# 1    HDFCBANK.NS  11435754127360    742.700012
# 2  BHARTIARTL.NS  11029219115008   1810.599976
# 3   ICICIBANK.NS   8887814062080   1239.699951
# 4        SBIN.NS   8806932152320    954.099976
# 5         TCS.NS   8312193548288   2297.399902
# 6  BAJFINANCE.NS   5528003018752    889.049988
# 7          LT.NS   5517530365952   4010.800049
# 8  HINDUNILVR.NS   4897253097472   2084.300049
# 9        INFY.NS   4867370254336   1202.500000

# %%
portfolio_size=int(input("Enter the amount you want to invest in your portfolio: "))
position_size=(portfolio_size/len(df))
position_size
# Out:
# 10000.0

# %%
df['no_of_shares_to_buy']= df['Latest Price'].apply(lambda price: math.floor(position_size/price))
df
# Out:
#           Ticker      Market Cap  Latest Price  no_of_shares_to_buy
# 0    RELIANCE.NS  17862863355904   1320.000000                    7
# 1    HDFCBANK.NS  11435754127360    742.700012                   13
# 2  BHARTIARTL.NS  11029219115008   1810.599976                    5
# 3   ICICIBANK.NS   8887814062080   1239.699951                    8
# 4        SBIN.NS   8806932152320    954.099976                   10
# 5         TCS.NS   8312193548288   2297.399902                    4
# 6  BAJFINANCE.NS   5528003018752    889.049988                   11
# 7          LT.NS   5517530365952   4010.800049                    2
# 8  HINDUNILVR.NS   4897253097472   2084.300049                    4
# 9        INFY.NS   4867370254336   1202.500000                    8
